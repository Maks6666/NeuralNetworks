# %% [markdown]
# Analysis of fraudulent activity on bank cards using ANN, also with data proprocessing
#
# Dataset taken from - https://www.kaggle.com/datasets/mlg-ulb/creditcardfraud

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import MinMaxScaler

from tensorflow import keras 
from keras.layers import Dense
from keras import Sequential

# %%
data = pd.read_csv("/Users/maxkucher/data_handling/ML_projects/creditcard.csv")
data
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# scaler = MinMaxScaler()

# for column in data.columns:
#     data[column] = scaler.fit_transform(data[[column]])

# %%
data
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
data.Class.value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
# oversampling of imbalanced dataset
maj = data[data["Class"] == 0]
min = data[data["Class"] == 1]

min = min.sample(len(maj), replace=True, random_state=42)
min
# Out:
#             Time         V1         V2         V3        V4         V5  \
# 33276    37167.0  -7.923891  -5.198360  -3.000024  4.420666   2.272194
# 239499  150138.0  -2.150855   2.187917  -3.430516  0.119476  -0.173210
# 154720  102676.0  -5.552122   5.678134  -9.775528  8.416295  -4.409844
# 142557   84789.0  -1.430864  -0.802529   1.123320  0.389760  -0.281214
# 41395    40662.0  -4.446847  -0.014793  -5.126307  6.945130   5.269255
# ...          ...        ...        ...        ...       ...        ...
# 229712  146022.0   0.908637   2.849024  -5.647343  6.009415   0.216656
# 15781    27219.0 -25.266355  14.323254 -26.823673  6.349248 -18.664251
# 251881  155542.0   1.868226   1.363077  -1.994934  4.173516   1.239751
# 154234  100924.0 -23.984747  16.697832 -22.209875  9.584969 -16.230439
# 281144  169966.0  -3.113832   0.585864  -5.399730  1.817092  -0.840618
#
#               V6         V7         V8         V9  ...        V21       V22  \
# ...

# %%
data = pd.concat([maj, min], ignore_index=True)

# %%
data
# Out:
#             Time         V1         V2         V3        V4         V5  \
# 0            0.0  -1.359807  -0.072781   2.536347  1.378155  -0.338321
# 1            0.0   1.191857   0.266151   0.166480  0.448154   0.060018
# 2            1.0  -1.358354  -1.340163   1.773209  0.379780  -0.503198
# 3            1.0  -0.966272  -0.185226   1.792993 -0.863291  -0.010309
# 4            2.0  -1.158233   0.877737   1.548718  0.403034  -0.407193
# ...          ...        ...        ...        ...       ...        ...
# 568625  146022.0   0.908637   2.849024  -5.647343  6.009415   0.216656
# 568626   27219.0 -25.266355  14.323254 -26.823673  6.349248 -18.664251
# 568627  155542.0   1.868226   1.363077  -1.994934  4.173516   1.239751
# 568628  100924.0 -23.984747  16.697832 -22.209875  9.584969 -16.230439
# 568629  169966.0  -3.113832   0.585864  -5.399730  1.817092  -0.840618
#
#               V6         V7         V8         V9  ...        V21       V22  \
# ...

# %%
x = data.drop(["Class", "Time"], axis="columns")
y = data["Class"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
x_train.shape
# Out:
# (454904, 29)

# %%
x_train
# Out:
#                V1         V2         V3        V4         V5        V6  \
# 41272    1.211857   0.448493   0.725859  2.313401  -0.051130  0.185785
# 422171  -6.750509   5.367416 -10.054635  9.064478  -7.968118 -2.263798
# 91749   -3.429189  -1.857509  -0.332810 -2.351560   0.460763  4.636389
# 156395   1.821216   0.176021   0.270568  3.910912  -0.172769  0.795613
# 302471 -10.850282   6.727466 -16.760583  8.425832 -10.252697 -4.192171
# ...           ...        ...        ...       ...        ...       ...
# 337489  -7.901421   2.720472  -7.885936  6.348334  -5.480119 -0.333059
# 338598 -27.848181  15.598193 -28.923756  6.418442 -20.346228 -4.828202
# 525780  -2.923827   1.524837  -3.018758  3.289291  -5.755542  2.218276
# 424358   1.934946   0.650678  -0.286957  3.987828   0.316052 -0.099449
# 16614   -0.442905   0.716727   1.256775  0.860048   1.210872  1.066390
#
#                V7         V8        V9        V10  ...       V20       V21  \
# ...

# %%
model = Sequential([
    Dense(20, input_shape=(29,), activation="relu"),
    Dense(13, activation="relu"),
    Dense(13, activation="relu"),
    Dense(8, activation="relu"),
    Dense(4, activation="relu"),
    Dense(1, activation="sigmoid")

])

model.compile(
    optimizer="adam",
    loss = "binary_crossentropy",
    metrics = ["accuracy"]
)

# %%
history = model.fit(x_train, y_train, epochs=10, verbose=0)

losses = history.history["loss"]
epochs = range(1, len(losses)+1)

plt.plot(epochs, losses, "r", label = "Losses")
plt.title("Loss/Epochs corelation")
plt.xlabel('Epochs')
plt.ylabel('Losses')
plt.legend()
plt.show()

# %%
model.fit(x_train, y_train, epochs=10)
# Out:
# Epoch 1/10
# 14216/14216 [==============================] - 10s 696us/step - loss: 0.0110 - accuracy: 0.9967
# Epoch 2/10
# 14216/14216 [==============================] - 10s 687us/step - loss: 0.0101 - accuracy: 0.9972
# Epoch 3/10
# 14216/14216 [==============================] - 10s 682us/step - loss: 0.0105 - accuracy: 0.9968
# Epoch 4/10
# 14216/14216 [==============================] - 10s 679us/step - loss: 0.0106 - accuracy: 0.9969
# Epoch 5/10
# 14216/14216 [==============================] - 10s 689us/step - loss: 0.0089 - accuracy: 0.9974
# Epoch 6/10
# 14216/14216 [==============================] - 10s 681us/step - loss: 0.0081 - accuracy: 0.9977
# Epoch 7/10
# 14216/14216 [==============================] - 10s 679us/step - loss: 0.0075 - accuracy: 0.9979
# Epoch 8/10
# 14216/14216 [==============================] - 10s 682us/step - loss: 0.0081 - accuracy: 0.9977
# Epoch 9/10
# 14216/14216 [==============================] - 10s 682us/step - loss: 0.0072 - accuracy: 0.9978
# ...

# %%
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_48 (Dense)            (None, 20)                600
#
#  dense_49 (Dense)            (None, 13)                273
#
#  dense_50 (Dense)            (None, 13)                182
#
#  dense_51 (Dense)            (None, 8)                 112
#
#  dense_52 (Dense)            (None, 4)                 36
#
#  dense_53 (Dense)            (None, 1)                 5
#
# ...
# Total params: 1208 (4.72 KB)
# Trainable params: 1208 (4.72 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.evaluate(x_test, y_test)
# Out:
# 3554/3554 [==============================] - 2s 413us/step - loss: 0.0115 - accuracy: 0.9967
# [0.011453560553491116, 0.9966850280761719]

# %%
preds = model.predict(x_test)

test_preds_array = []

for pred in preds:
    if pred >= 0.5:
        test_preds_array.append(1)
    elif pred < 0.5:
        test_preds_array.append(0)

test_preds_array = np.array(test_preds_array)
# Out:
# 3554/3554 [==============================] - 1s 386us/step

# %%
preds_frame = pd.DataFrame({"Predictions": test_preds_array.squeeze(), "Actuals": y_test.squeeze()})
preds_frame
# Out:
#         Predictions  Actuals
# 434993            1        1
# 210862            0        0
# 14826             0        0
# 158866            0        0
# 280730            0        0
# ...             ...      ...
# 99915             0        0
# 247756            0        0
# 205048            0        0
# 185691            0        0
# 291286            1        1
#
# [113726 rows x 2 columns]

# %%
preds = model.predict(x)

preds_array = []

for pred in preds:
    if pred >= 0.5:
        preds_array.append(1)
    elif pred < 0.5:
        preds_array.append(0)

data["Predictions"] = np.array(preds_array)
# Out:
# 17770/17770 [==============================] - 7s 407us/step

# %%
data
# Out:
#             Time         V1         V2         V3        V4         V5  \
# 0            0.0  -1.359807  -0.072781   2.536347  1.378155  -0.338321
# 1            0.0   1.191857   0.266151   0.166480  0.448154   0.060018
# 2            1.0  -1.358354  -1.340163   1.773209  0.379780  -0.503198
# 3            1.0  -0.966272  -0.185226   1.792993 -0.863291  -0.010309
# 4            2.0  -1.158233   0.877737   1.548718  0.403034  -0.407193
# ...          ...        ...        ...        ...       ...        ...
# 568625  146022.0   0.908637   2.849024  -5.647343  6.009415   0.216656
# 568626   27219.0 -25.266355  14.323254 -26.823673  6.349248 -18.664251
# 568627  155542.0   1.868226   1.363077  -1.994934  4.173516   1.239751
# 568628  100924.0 -23.984747  16.697832 -22.209875  9.584969 -16.230439
# 568629  169966.0  -3.113832   0.585864  -5.399730  1.817092  -0.840618
#
#               V6         V7         V8         V9  ...       V22       V23  \
# ...

# %%
cm = confusion_matrix(test_preds_array, y_test)
cm
# Out:
# array([[56587,     0],
#        [  377, 56762]])

# %%
plt.figure(figsize=(15, 6))
sn.heatmap(cm, annot=True)
plt.xlabel("Predictions")
plt.xlabel("Actuals")
# Out:
# Text(0.5, 36.72222222222221, 'Actuals')
